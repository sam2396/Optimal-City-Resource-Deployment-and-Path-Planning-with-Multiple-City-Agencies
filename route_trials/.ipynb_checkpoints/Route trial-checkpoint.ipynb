# %%
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import numpy as np
from pulp import *
import seaborn as sn

# %%
df=pd.read_csv('../../../Datasets/cop_data.csv')
df.head()
# Out:
#            X          Y                                ID Case_Number  \
# 0 -77.607990  43.183680  d981912bde17ff11baeec440d2962c55   20-180265
# 1 -77.643147  43.141723  9aed9ae5ee7f83638ee33ccff49cf6b9   20-180404
# 2 -77.611200  43.178448  b0c3f83c934aeea9486ccc2362e0cee6   20-179396
# 3 -77.613357  43.168276  b83cd8b57bb9048cca4830620cbfab07   20-179526
# 4 -77.589725  43.181775  42bb767348c1f8a5e4c085b67ab14732   20-177327
#
#                 Address           Occurred_Date  Occurred_Month  \
# 0       1010 Joseph Ave  2020/08/09 04:00:00+00               8
# 1         294 Rugby Ave  2020/08/09 04:00:00+00               8
# 2         77 Ketchum St  2020/08/08 04:00:00+00               8
# 3  123 Upper Falls Blvd  2020/08/08 04:00:00+00               8
# 4       334 Roycroft Dr  2020/08/06 04:00:00+00               8
#
#    Occurred_Year Crime_Type Multiple_Shooting Gender   Race     Ethnicity  \
# 0           2020   Shooting                No      M  BLACK  NON HISPANIC
# 1           2020   Shooting                No      F  BLACK  NON HISPANIC
# 2           2020   Shooting                No      M  WHITE  NON HISPANIC
# 3           2020   Shooting                No      M  BLACK  NON HISPANIC
# 4           2020   Shooting               Yes      M  BLACK  NON HISPANIC
#
#    Victim_Age Victim_Age_Band   Latitude  Longitude  ObjectId
# 0          23           15-24  43.183680 -77.607990         1
# 1          28           25-44  43.141723 -77.643147         2
# 2          49        45-Older  43.178448 -77.611200         3
# 3          23           15-24  43.168276 -77.613357         4
# 4          22           15-24  43.181775 -77.589725         5

# %%
df['Latitude']
# Out:
# 0     43.183680
# 1     43.141723
# 2     43.178448
# 3     43.168276
# 4     43.181775
# 5     43.181775
# 6     43.126591
# 7     43.146168
# 8     43.169300
# 9     43.179133
# 10    43.179133
# 11    43.172693
# 12    43.181901
# Name: Latitude, dtype: float64

# %%
df['Longitude']
# Out:
# 0    -77.607990
# 1    -77.643147
# 2    -77.611200
# 3    -77.613357
# 4    -77.589725
# 5    -77.589725
# 6    -77.614345
# 7    -77.646772
# 8    -77.580698
# 9    -77.648424
# 10   -77.648424
# 11   -77.609300
# 12   -77.618138
# Name: Longitude, dtype: float64

# %%
df.shape
# Out:
# (13, 18)

# %%
import haversine as hs
from haversine import Unit

# %%
df['coordinate'] = list(zip(df['Latitude'],df['Longitude']))
df.head()
# Out:
#            X          Y                                ID Case_Number  \
# 0 -77.607990  43.183680  d981912bde17ff11baeec440d2962c55   20-180265
# 1 -77.643147  43.141723  9aed9ae5ee7f83638ee33ccff49cf6b9   20-180404
# 2 -77.611200  43.178448  b0c3f83c934aeea9486ccc2362e0cee6   20-179396
# 3 -77.613357  43.168276  b83cd8b57bb9048cca4830620cbfab07   20-179526
# 4 -77.589725  43.181775  42bb767348c1f8a5e4c085b67ab14732   20-177327
#
#                 Address           Occurred_Date  Occurred_Month  \
# 0       1010 Joseph Ave  2020/08/09 04:00:00+00               8
# 1         294 Rugby Ave  2020/08/09 04:00:00+00               8
# 2         77 Ketchum St  2020/08/08 04:00:00+00               8
# 3  123 Upper Falls Blvd  2020/08/08 04:00:00+00               8
# 4       334 Roycroft Dr  2020/08/06 04:00:00+00               8
#
#    Occurred_Year Crime_Type Multiple_Shooting Gender   Race     Ethnicity  \
# 0           2020   Shooting                No      M  BLACK  NON HISPANIC
# 1           2020   Shooting                No      F  BLACK  NON HISPANIC
# 2           2020   Shooting                No      M  WHITE  NON HISPANIC
# 3           2020   Shooting                No      M  BLACK  NON HISPANIC
# 4           2020   Shooting               Yes      M  BLACK  NON HISPANIC
#
#    Victim_Age Victim_Age_Band   Latitude  Longitude  ObjectId  \
# 0          23           15-24  43.183680 -77.607990         1
# 1          28           25-44  43.141723 -77.643147         2
# 2          49        45-Older  43.178448 -77.611200         3
# 3          23           15-24  43.168276 -77.613357         4
# 4          22           15-24  43.181775 -77.589725         5
#
#                                 coordinate
# 0        (43.1836795360001, -77.607990462)
# 1       (43.14172340100001, -77.643147095)
# 2    (43.1784481240001, -77.6112000269999)
# 3  (43.16827618399999, -77.61335654399991)
# 4      (43.181775168000094, -77.589725243)

# %%
def dist_from(loc1,loc2): 
    dist=hs.haversine(loc1,loc2)
    return round(dist,2)

# %%
# parse location one by one to dist_from
for _,row in df.iterrows():
    df[row.ID]=df['coordinate'].apply(lambda x: dist_from(row.coordinate,x))

# %%
df.head()
# Out:
#            X          Y                                ID Case_Number  \
# 0 -77.607990  43.183680  d981912bde17ff11baeec440d2962c55   20-180265
# 1 -77.643147  43.141723  9aed9ae5ee7f83638ee33ccff49cf6b9   20-180404
# 2 -77.611200  43.178448  b0c3f83c934aeea9486ccc2362e0cee6   20-179396
# 3 -77.613357  43.168276  b83cd8b57bb9048cca4830620cbfab07   20-179526
# 4 -77.589725  43.181775  42bb767348c1f8a5e4c085b67ab14732   20-177327
#
#                 Address           Occurred_Date  Occurred_Month  \
# 0       1010 Joseph Ave  2020/08/09 04:00:00+00               8
# 1         294 Rugby Ave  2020/08/09 04:00:00+00               8
# 2         77 Ketchum St  2020/08/08 04:00:00+00               8
# 3  123 Upper Falls Blvd  2020/08/08 04:00:00+00               8
# 4       334 Roycroft Dr  2020/08/06 04:00:00+00               8
#
#    Occurred_Year Crime_Type Multiple_Shooting  ...  \
# 0           2020   Shooting                No  ...
# 1           2020   Shooting                No  ...
# 2           2020   Shooting                No  ...
# 3           2020   Shooting                No  ...
# 4           2020   Shooting               Yes  ...
#
#   b83cd8b57bb9048cca4830620cbfab07 42bb767348c1f8a5e4c085b67ab14732  \
# 0                             1.77                             1.50
# 1                             3.82                             6.21
# 2                             1.14                             1.78
# 3                             0.00                             2.43
# 4                             2.43                             0.00
#
#   a8c5e088b79b16709df3ce1589438e4b  1642e9ea9f20bc6c190560580241ad24  \
# 0                             1.50                              6.37
# 1                             6.21                              2.88
# 2                             1.78                              5.77
# 3                             2.43                              4.64
# 4                             0.00                              6.45
#
#   7c4ff4e2a92a48af3a1bebb390a4fdbc  5e631196f8d60399474687757b4fe570  \
# 0                             5.22                              2.73
# 1                             0.58                              5.92
# 2                             4.61                              2.67
# 3                             3.66                              2.65
# 4                             6.09                              1.57
#
#    d604b745f7537a66e8883bef6da030d6  7b512d2bf479e7f0b509086593a5412d  \
# 0                              3.32                              3.32
# 1                              4.18                              4.18
# 2                              3.02                              3.02
# 3                              3.09                              3.09
# 4                              4.77                              4.77
#
#   b60d6b2da56ee3b3cc4e9a78cc72b73c  04bf6b9efe7f0b98c20e83dde9c32e19
# 0                             1.23                              0.85
# 1                             4.40                              4.91
# 2                             0.66                              0.68
# 3                             0.59                              1.56
# 4                             1.88                              2.30
#
# [5 rows x 32 columns]

# %%
distances_df=df.iloc[:,19:4183]
#distances_df.index=df.ID
distances_df.insert(0, 'ID', df.ID)

distances_df
# Out:
#                                   ID  d981912bde17ff11baeec440d2962c55  \
# 0   d981912bde17ff11baeec440d2962c55                              0.00
# 1   9aed9ae5ee7f83638ee33ccff49cf6b9                              5.47
# 2   b0c3f83c934aeea9486ccc2362e0cee6                              0.64
# 3   b83cd8b57bb9048cca4830620cbfab07                              1.77
# 4   42bb767348c1f8a5e4c085b67ab14732                              1.50
# 5   a8c5e088b79b16709df3ce1589438e4b                              1.50
# 6   1642e9ea9f20bc6c190560580241ad24                              6.37
# 7   7c4ff4e2a92a48af3a1bebb390a4fdbc                              5.22
# 8   5e631196f8d60399474687757b4fe570                              2.73
# 9   d604b745f7537a66e8883bef6da030d6                              3.32
# 10  7b512d2bf479e7f0b509086593a5412d                              3.32
# 11  b60d6b2da56ee3b3cc4e9a78cc72b73c                              1.23
# 12  04bf6b9efe7f0b98c20e83dde9c32e19                              0.85
#
#     9aed9ae5ee7f83638ee33ccff49cf6b9  b0c3f83c934aeea9486ccc2362e0cee6  \
# 0                               5.47                              0.64
# 1                               0.00                              4.84
# 2                               4.84                              0.00
# 3                               3.82                              1.14
# 4                               6.21                              1.78
# 5                               6.21                              1.78
# 6                               2.88                              5.77
# 7                               0.58                              4.61
# 8                               5.92                              2.67
# 9                               4.18                              3.02
# 10                              4.18                              3.02
# 11                              4.40                              0.66
# 12                              4.91                              0.68
#
#     b83cd8b57bb9048cca4830620cbfab07  42bb767348c1f8a5e4c085b67ab14732  \
# 0                               1.77                              1.50
# 1                               3.82                              6.21
# 2                               1.14                              1.78
# 3                               0.00                              2.43
# 4                               2.43                              0.00
# 5                               2.43                              0.00
# 6                               4.64                              6.45
# 7                               3.66                              6.09
# 8                               2.65                              1.57
# 9                               3.09                              4.77
# 10                              3.09                              4.77
# 11                              0.59                              1.88
# 12                              1.56                              2.30
#
#     a8c5e088b79b16709df3ce1589438e4b  1642e9ea9f20bc6c190560580241ad24  \
# 0                               1.50                              6.37
# 1                               6.21                              2.88
# 2                               1.78                              5.77
# 3                               2.43                              4.64
# 4                               0.00                              6.45
# 5                               0.00                              6.45
# 6                               6.45                              0.00
# 7                               6.09                              3.41
# 8                               1.57                              5.48
# 9                               4.77                              6.46
# 10                              4.77                              6.46
# 11                              1.88                              5.14
# 12                              2.30                              6.16
#
#     7c4ff4e2a92a48af3a1bebb390a4fdbc  5e631196f8d60399474687757b4fe570  \
# 0                               5.22                              2.73
# 1                               0.58                              5.92
# 2                               4.61                              2.67
# 3                               3.66                              2.65
# 4                               6.09                              1.57
# 5                               6.09                              1.57
# 6                               3.41                              5.48
# 7                               0.00                              5.94
# 8                               5.94                              0.00
# 9                               3.67                              5.60
# 10                              3.67                              5.60
# 11                              4.24                              2.35
# 12                              4.60                              3.34
#
#     d604b745f7537a66e8883bef6da030d6  7b512d2bf479e7f0b509086593a5412d  \
# 0                               3.32                              3.32
# 1                               4.18                              4.18
# 2                               3.02                              3.02
# 3                               3.09                              3.09
# 4                               4.77                              4.77
# 5                               4.77                              4.77
# 6                               6.46                              6.46
# 7                               3.67                              3.67
# 8                               5.60                              5.60
# 9                               0.00                              0.00
# 10                              0.00                              0.00
# 11                              3.25                              3.25
# 12                              2.47                              2.47
#
#     b60d6b2da56ee3b3cc4e9a78cc72b73c  04bf6b9efe7f0b98c20e83dde9c32e19
# 0                               1.23                              0.85
# 1                               4.40                              4.91
# 2                               0.66                              0.68
# 3                               0.59                              1.56
# 4                               1.88                              2.30
# 5                               1.88                              2.30
# 6                               5.14                              6.16
# 7                               4.24                              4.60
# 8                               2.35                              3.34
# 9                               3.25                              2.47
# 10                              3.25                              2.47
# 11                              0.00                              1.25
# 12                              1.25                              0.00

# %%
dist_dict={}

# %%
#positions to be plotted
locations = dict( ( ID, (df[['ID','Latitude','Longitude']].loc[ID, 'Longitude'], df[['ID','Latitude','Longitude']].loc[ID, 'Latitude']) ) for ID in df.index)
locations
# Out:
# {0: (-77.607990462, 43.1836795360001),
#  1: (-77.643147095, 43.14172340100001),
#  2: (-77.6112000269999, 43.1784481240001),
#  3: (-77.61335654399991, 43.16827618399999),
#  4: (-77.589725243, 43.181775168000094),
#  5: (-77.589725243, 43.181775168000094),
#  6: (-77.61434480299991, 43.1265908730001),
#  7: (-77.646771838, 43.146168239000104),
#  8: (-77.58069826399999, 43.169300143),
#  9: (-77.648424429, 43.179133138999994),
#  10: (-77.648424429, 43.179133138999994),
#  11: (-77.609300162, 43.172693386999995),
#  12: (-77.6181375, 43.181900602)}

# %%
for l in locations:
    lo = locations[l]
    plt.plot(lo[0],lo[1],'o')
    plt.text(lo[0]+.01,lo[1],l,horizontalalignment='center',verticalalignment='center')
    
plt.gca().axis('off');

# %%
# get distance in a dictionary form
distances = dict( ((l1,l2), distances_df.iloc[l1, l2] ) for l1 in locations for l2 in locations if l1!=l2)

# %%
K = 3 #the number vehicles/people deployed

# %%
#problem
prob=LpProblem("vehicle", LpMinimize)

# %%
#indicates if location i is connected to location j along route 
indicator = LpVariable.dicts('indicator',distances, 0,1,LpBinary)
#elimiate subtours
eliminator = LpVariable.dicts('eliminator', df.ID, 0, len(df.ID)-1, LpInteger)

# %%
type(indicator)
# Out:
# dict

# %%
type(distances)
# Out:
# dict

# %%
#constraints
for k in df.ID:
    cap = 1 if k != '9aed9ae5ee7f83638ee33ccff49cf6b9' else K
    #inward possible route
    prob+= lpSum([ indicator[(i,k)] for i in df.ID if (i,k) in indicator]) ==cap
    #outward possible route
    prob+=lpSum([ indicator[(k,i)] for i in df.ID if (k,i) in indicator]) ==cap
    
#subtour elimination
num=len(df.ID)/K
for i in df.ID:
    for j in df.ID:
        if i != j and (i != '9aed9ae5ee7f83638ee33ccff49cf6b9' and j!= '9aed9ae5ee7f83638ee33ccff49cf6b9') and (i,j) in indicator:
            prob += eliminator[i] - eliminator[j] <= (num)*(1-indicator[(i,j)]) - 1

# %%
# %time prob.solve()
print(LpStatus[prob.status])
# Out:
# CPU times: user 2.56 ms, sys: 8.75 ms, total: 11.3 ms
# Wall time: 78 ms
# Infeasible

# %%
feasible_edges = [ e for e in indicator if value(indicator[e]) != 0 ]

def get_next_loc(initial):
    '''to get the next edge'''
    edges = [e for e in feasible_edges if e[0]==initial]
    for e in edges:
        feasible_edges.remove(e)
    return edges

# %%
routes = get_next_loc('9aed9ae5ee7f83638ee33ccff49cf6b9')
routes = [ [e] for e in route ]

for r in routes:
    while r[-1][1] !='9aed9ae5ee7f83638ee33ccff49cf6b9':
        r.append(get_next_loc(r[-1][1])[-1])

# %%
for r in routes:
    print(' -> '.join([ a for a,b in r]+['9aed9ae5ee7f83638ee33ccff49cf6b9']))

# %%
#outline the routes
coloured_loc = [np.random.rand(3) for i in range(len(route))]
for r,co in zip(routes,coloured_loc):
    for a,b in r:
        l1,l2 = locations[a], locations[b]
        plt.plot([l1[0],l2[0]],[l1[1],l2[1]], coloured_loc=co)

# %%
for l in locations:
    lo = locations[l]
    plt.plot(lo[0],lo[1],'o')
    plt.text(lo[0]+.01,lo[1],l,horizontalalignment='center',verticalalignment='center')
    
    
plt.title('%d '%K + 'Vehicle routes' if K > 1 else 'Vehicle route')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()
